# %%
# %matplotlib inline

import torch
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load raw Seattle data
with open('../data/raw_seattle.csv', 'r') as csv_file:
    df = pd.read_csv(csv_file)
    
del df['Notes']  # A useless column

# %%
df.columns
# Out:
# Index(['Jobtitle', 'Female Avg Hrly Rate', 'No. Female Empl',
#        'Average of Female MONTHS LONGEVITY IN CURRENT CLASSIFICATION ',
#        'Male Avg Hrly Rate', 'No. Male Empl',
#        'Average of Male MONTHS LONGEVITY IN CURRENT CLASSIFICATION ',
#        'Total Avg Hrly Rate', 'Total No. Empl',
#        'Total Average of MONTHS LONGEVITY IN CURRENT CLASSIFICATION ',
#        'Ratio of women's hourly rate to men's hourly rate - percentage'],
#       dtype='object')

# %%
# Shorten the names of the columns
df = df.rename(columns={'Female Avg Hrly Rate': 'F Rate',
                        'No. Female Empl': '#F Empl',
                        'Average of Female MONTHS LONGEVITY IN CURRENT CLASSIFICATION ': 'Avg. F Long.',
                        'Male Avg Hrly Rate': 'M Rate',
                        'No. Male Empl': '#M Empl',
                        'Average of Male MONTHS LONGEVITY IN CURRENT CLASSIFICATION ': 'Avg. M Long.',
                        'Total Avg Hrly Rate': 'Total Rate',
                        'Total No. Empl': 'Total # Empl',
                        'Total Average of MONTHS LONGEVITY IN CURRENT CLASSIFICATION ': 'Total Avg. Long.',
                        "Ratio of women's hourly rate to men's hourly rate - percentage": '(W Rate / M Rate)'})

# Convert the percent signs in the last column to numbers
def convert_pct(x):
    if isinstance(x, str) and x[-1] == '%':
        return float(x[:-1]) / 100.0
    else:
        return x

df['(W Rate / M Rate)'] = df['(W Rate / M Rate)'].apply(convert_pct)

# Convert the other numeric columns to numbers
numeric_cols = ['F Rate',
                '#F Empl',
                'Avg. F Long.',
                'M Rate',
                '#M Empl',
                'Avg. M Long.',
                'Total Rate',
                'Total # Empl',
                'Total Avg. Long.']

df[numeric_cols] = df[numeric_cols].apply(pd.to_numeric)

# %%
df = df.dropna()  # Remove missing values
df = df[df['Total # Empl'] > 1]  # Departments with only one employee don't give a good representation
df = df[:-1]  # Remove grand total line since it would throw off regression

# %%
# df.to_csv('../data/seattle_partially_cleaned.csv')

# %%
df_without_redundancy = df.copy()
del df_without_redundancy['Total Rate']
del df_without_redundancy['Total # Empl']
del df_without_redundancy['Total Avg. Long.']
df_without_redundancy
# Out:
#                     Jobtitle  F Rate  #F Empl  Avg. F Long.  M Rate  #M Empl  \
# 0                 Accountant   30.58     23.0         88.96   30.28      7.0
# 1            Accountant,Prin   38.75     23.0         59.96   37.64      7.0
# 2              Accountant,Sr   34.48     23.0         60.61   33.89      6.0
# 3                   Act Exec   43.10      4.0        146.00   42.02      7.0
# 5             Actg Tech I-BU   22.56     10.0         81.80   22.56      2.0
# 6               Actg Tech II   23.98      7.0        112.71   24.35      1.0
# 7            Actg Tech II-BU   24.19     74.0        103.23   24.21     18.0
# 9           Actg Tech III-BU   26.69     32.0         89.97   26.18      5.0
# 831         Warehouser,Chief   30.88      2.0         85.50   30.88      9.0
# 833         Warehouser,Sr-BU   26.42     12.0        104.42   26.40     20.0
# 834            Warehouser-BU   24.08      4.0        127.25   24.08     14.0
# 842    Wtr Meter Repairer,Sr   27.67      1.0        183.00   27.67      2.0
# 845             Wtr Pipe Wkr   30.18      2.0        193.50   30.18     25.0
# 846   Wtr Pipe Wkr Sr-WDM II   33.64      4.0         85.00   33.64     27.0
# 848       Wtr Pipe Wkr-WDM I   30.46      1.0         88.00   29.94     15.0
# 849       Wtr Quality Anlyst   33.69      3.0        117.00   33.69      3.0
# 851    Wtr Quality Anlyst,Sr   36.30      2.0        125.50   36.30      1.0
# 852  Wtr Quality Anlyst,Supv   39.20      1.0         90.00   39.20      1.0
# 856           Wtr Syst Op,Sr   41.72      1.0        150.00   41.72      1.0
# 858         Wtr Treatment CC   36.30      1.0        173.00   36.30      1.0
# 862   Wtr Treatment Op-WDM I   28.22      2.0         88.00   27.52      3.0
# 871              Grand Total   35.35   3600.0         81.83   39.04   6285.0
#
#      Avg. M Long.  (W Rate / M Rate)
# 0           85.71             1.0100
# 1            7.00             1.0295
# 2           43.67             1.0175
# 3          106.29             1.0256
# 5           35.50             1.0000
# 6           75.00             0.9849
# 7          134.50             0.9995
# 9           51.20             1.0196
# 12          46.00             1.0270
# 13          91.17             1.0001
# 14          42.50             1.0173
# 15          76.50             1.0061
# 16          94.50             0.9939
# 17          53.67             1.0003
# 19         129.00             1.0000
# 20         123.00             1.0000
# 21          49.00             1.0169
# 22          72.00             1.0126
# 24          83.00             0.9852
# 26         141.00             0.9928
# 27         158.00             1.0000
# 29         102.50             1.0000
# 31          55.50             1.0101
# 32         142.17             1.0000
# 36          76.00             1.0000
# 37          71.33             1.0000
# 41         223.00             1.0000
# 42          56.00             0.9856
# 43          80.86             1.0058
# 46          65.00             1.0000
# ..            ...                ...
# 802         84.50             1.0197
# 805         77.00             1.0596
# 806        108.33             1.0033
# 807        103.88             1.0023
# 809         80.00             0.9961
# 810         75.67             0.9983
# 812         59.00             1.0000
# 813          3.71             1.0078
# 817         54.80             0.9856
# 819        116.31             1.0000
# 820        105.33             1.0000
# 821        114.50             1.0000
# 822         98.00             0.9744
# 825        156.50             0.9923
# 827         80.44             1.0246
# 828         16.00             1.0000
# 831        138.67             1.0000
# 833        118.95             1.0006
# 834        127.57             1.0000
# 842        146.50             1.0000
# 845         95.56             1.0000
# 846         67.15             1.0000
# 848         24.87             1.0175
# 849        125.67             1.0000
# 851         57.00             1.0000
# 852         91.00             1.0000
# 856        120.00             1.0000
# 858        164.00             1.0000
# 862         61.67             1.0256
# 871         78.38             0.9055
#
# [434 rows x 8 columns]
